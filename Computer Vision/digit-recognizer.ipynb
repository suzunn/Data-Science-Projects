# %% [markdown]
# <a href="https://www.kaggle.com/code/notsau/digit-recognizer?scriptVersionId=161445013" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %% [markdown]
# # EDA

# %%
data = pd.read_csv("/kaggle/input/digit-recognizer/train.csv")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Veri setinizin boyutu
total_samples = 42000

your_data = pd.read_csv("train.csv")

# Veri setinin indekslerini sıfırlama ve karıştırma
shuffled_data = your_data.sample(frac=1, random_state=42)

# Veri setini train ve test olarak ayırma
train, test = train_test_split(shuffled_data, test_size=1/3, random_state=42)

# %%
test
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 20091      7       0       0       0       0       0       0       0       0
# 19710      1       0       0       0       0       0       0       0       0
# 29088      0       0       0       0       0       0       0       0       0
# 26519      4       0       0       0       0       0       0       0       0
# 36618      5       0       0       0       0       0       0       0       0
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2611       9       0       0       0       0       0       0       0       0
# 28803      4       0       0       0       0       0       0       0       0
# 3292       2       0       0       0       0       0       0       0       0
# 4796       6       0       0       0       0       0       0       0       0
# 8317       5       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 20091       0  ...         0         0         0         0         0
# 19710       0  ...         0         0         0         0         0
# 29088       0  ...         0         0         0         0         0
# 26519       0  ...         0         0         0         0         0
# 36618       0  ...         0         0         0         0         0
# ...       ...  ...       ...       ...       ...       ...       ...
# 2611        0  ...         0         0         0         0         0
# 28803       0  ...         0         0         0         0         0
# 3292        0  ...         0         0         0         0         0
# 4796        0  ...         0         0         0         0         0
# 8317        0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 20091         0         0         0         0         0
# 19710         0         0         0         0         0
# 29088         0         0         0         0         0
# 26519         0         0         0         0         0
# 36618         0         0         0         0         0
# ...         ...       ...       ...       ...       ...
# 2611          0         0         0         0         0
# 28803         0         0         0         0         0
# 3292          0         0         0         0         0
# 4796          0         0         0         0         0
# 8317          0         0         0         0         0
#
# [14000 rows x 785 columns]

# %%
train.shape
# Out:
# (28000, 785)

# %%
test.shape
# Out:
# (14000, 785)

# %% [markdown]
# # Feature Engineering

# %%
train_images = train.drop("label", axis=1).values
train_labels = train["label"].values

test_images = test.drop("label", axis=1).values
test_labels = test["label"].values

train_images=train_images/255.0
test_images=test_images/255.0

# %%
train_images = train_images.reshape(28000, 784)
test_images = test_images.reshape(14000, 784)
test_images = test_images.astype("float32")
train_images = train_images.astype("float32")

# %% [markdown]
# # Modelling

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation = "relu", input_shape =(784,)),
    tf.keras.layers.Dense(64, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")])
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(train_images, train_labels, batch_size = 120, epochs=40, verbose = 1, validation_data = (test_images, test_labels))
# Out:
# WARNING:tensorflow:From C:\Users\slymn\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
#
# WARNING:tensorflow:From C:\Users\slymn\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
#
#
# WARNING:tensorflow:From C:\Users\slymn\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
#
#
# Epoch 1/40
#
# WARNING:tensorflow:From C:\Users\slymn\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#
#
# WARNING:tensorflow:From C:\Users\slymn\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
#
# 234/234 [==============================] - 2s 3ms/step - loss: 0.5805 - accuracy: 0.8334 - val_loss: 0.2693 - val_accuracy: 0.9229
#
# Epoch 2/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.2277 - accuracy: 0.9339 - val_loss: 0.2024 - val_accuracy: 0.9408
#
# Epoch 3/40
#
# 234/234 [==============================] - 1s 2ms/step - loss: 0.1690 - accuracy: 0.9511 - val_loss: 0.1679 - val_accuracy: 0.9511
#
# Epoch 4/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.1329 - accuracy: 0.9614 - val_loss: 0.1549 - val_accuracy: 0.9554
#
# Epoch 5/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.1092 - accuracy: 0.9675 - val_loss: 0.1343 - val_accuracy: 0.9600
#
# Epoch 6/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0912 - accuracy: 0.9732 - val_loss: 0.1297 - val_accuracy: 0.9624
#
# Epoch 7/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0756 - accuracy: 0.9782 - val_loss: 0.1230 - val_accuracy: 0.9639
#
# Epoch 8/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0663 - accuracy: 0.9808 - val_loss: 0.1241 - val_accuracy: 0.9639
#
# Epoch 9/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0561 - accuracy: 0.9843 - val_loss: 0.1256 - val_accuracy: 0.9631
#
# Epoch 10/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0487 - accuracy: 0.9854 - val_loss: 0.1201 - val_accuracy: 0.9644
#
# Epoch 11/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0445 - accuracy: 0.9868 - val_loss: 0.1244 - val_accuracy: 0.9658
#
# Epoch 12/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0360 - accuracy: 0.9901 - val_loss: 0.1267 - val_accuracy: 0.9643
#
# Epoch 13/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0310 - accuracy: 0.9912 - val_loss: 0.1203 - val_accuracy: 0.9669
#
# Epoch 14/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0253 - accuracy: 0.9936 - val_loss: 0.1227 - val_accuracy: 0.9670
#
# Epoch 15/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0217 - accuracy: 0.9946 - val_loss: 0.1246 - val_accuracy: 0.9661
#
# Epoch 16/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9949 - val_loss: 0.1314 - val_accuracy: 0.9654
#
# Epoch 17/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.1365 - val_accuracy: 0.9660
#
# Epoch 18/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 0.1307 - val_accuracy: 0.9669
#
# Epoch 19/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.1306 - val_accuracy: 0.9686
#
# Epoch 20/40
#
# 234/234 [==============================] - 1s 4ms/step - loss: 0.0092 - accuracy: 0.9986 - val_loss: 0.1391 - val_accuracy: 0.9673
#
# Epoch 21/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0089 - accuracy: 0.9982 - val_loss: 0.1369 - val_accuracy: 0.9690
#
# Epoch 22/40
#
# 234/234 [==============================] - 1s 4ms/step - loss: 0.0072 - accuracy: 0.9988 - val_loss: 0.1459 - val_accuracy: 0.9665
#
# Epoch 23/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.1623 - val_accuracy: 0.9639
#
# Epoch 24/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.1875 - val_accuracy: 0.9578
#
# Epoch 25/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.1714 - val_accuracy: 0.9632
#
# Epoch 26/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.1565 - val_accuracy: 0.9675
#
# Epoch 27/40
#
# 234/234 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.1613 - val_accuracy: 0.9661
#
# Epoch 28/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.1731 - val_accuracy: 0.9666
#
# Epoch 29/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.1539 - val_accuracy: 0.9693
#
# Epoch 30/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9684
#
# Epoch 31/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 9.7635e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9700
#
# Epoch 32/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 7.7684e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9702
#
# Epoch 33/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 6.6509e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9704
#
# Epoch 34/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 5.7664e-04 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9705
#
# Epoch 35/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 5.1740e-04 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9701
#
# Epoch 36/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 4.6151e-04 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9709
#
# Epoch 37/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 4.2603e-04 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9709
#
# Epoch 38/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 4.0705e-04 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9709
#
# Epoch 39/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 3.5068e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9704
#
# Epoch 40/40
#
# 234/234 [==============================] - 1s 3ms/step - loss: 3.5353e-04 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9701

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print("Accuracy =  %2f" % (accuracy*100))
# Out:
# 438/438 [==============================] - 1s 1ms/step - loss: 0.1727 - accuracy: 0.9701
#
# Accuracy =  97.014284

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Train", "Test"], loc="upper left")
plt.show()
