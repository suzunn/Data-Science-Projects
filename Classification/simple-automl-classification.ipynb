# %% [markdown]
# <a href="https://www.kaggle.com/code/notsau/simple-automl-classification?scriptVersionId=161452218" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/social.csv")

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# # Modelling

# %%
# !pip install pycaret

# %%
from pycaret.classification import*

# %%
setup(df,target="Purchased")
# Out:
# <style type="text/css">
# #T_23d77_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_23d77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23d77_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_23d77_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23d77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23d77_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_23d77_row0_col1" class="data row0 col1" >7078</td>
#     </tr>
#     <tr>
#       <th id="T_23d77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23d77_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_23d77_row1_col1" class="data row1 col1" >Purchased</td>
#     </tr>
#     <tr>
#       <th id="T_23d77_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_ccb83 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model("qda")
#en iyi modelin qda olduğunu gördük ve onu tekrar çalıştırdık
# Out:
# <style type="text/css">
# #T_fb43c_row10_col0, #T_fb43c_row10_col1, #T_fb43c_row10_col2, #T_fb43c_row10_col3, #T_fb43c_row10_col4, #T_fb43c_row10_col5, #T_fb43c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fb43c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb43c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fb43c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fb43c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fb43c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fb43c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fb43c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fb43c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(best_model, plot='auc')
